# %%
import requests
import json
import pandas as pd

# %%
response=requests.get("https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=MSFT&apikey=TG5XV6MAKKAIRCTT")

# %%
response.json()
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes',
#   '2. Symbol': 'MSFT',
#   '3. Last Refreshed': '2019-09-13',
#   '4. Output Size': 'Compact',
#   '5. Time Zone': 'US/Eastern'},
#  'Time Series (Daily)': {'2019-09-13': {'1. open': '137.7800',
#    '2. high': '138.0600',
#    '3. low': '136.5700',
#    '4. close': '137.3200',
#    '5. volume': '16554185'},
#   '2019-09-12': {'1. open': '137.8500',
#    '2. high': '138.4200',
#    '3. low': '136.8700',
#    '4. close': '137.5200',
#    '5. volume': '25750600'},
#   '2019-09-11': {'1. open': '135.9100',
#    '2. high': '136.2700',
#    '3. low': '135.0900',
#    '4. close': '136.1200',
#    '5. volume': '24726100'},
#   '2019-09-10': {'1. open': '136.8000',
#    '2. high': '136.8900',
#    '3. low': '134.5100',
#    '4. close': '136.0800',
#    '5. volume': '28903400'},
#   '2019-09-09': {'1. open': '139.5900',
#    '2. high': '139.7500',
#    '3. low': '136.4600',
#    '4. close': '137.5200',
# ...

# %%
len(response.json()['Time Series (Daily)'])
# Out:
# 100

# %%
for key in response.json()['Time Series (Daily)']:
    print(key,response.json()['Time Series (Daily)'][key])
    stock
# Out:
# 2019-09-13 {'1. open': '137.7800', '2. high': '138.0600', '3. low': '136.5700', '4. close': '137.3200', '5. volume': '16554185'}
# 2019-09-12 {'1. open': '137.8500', '2. high': '138.4200', '3. low': '136.8700', '4. close': '137.5200', '5. volume': '25750600'}
# 2019-09-11 {'1. open': '135.9100', '2. high': '136.2700', '3. low': '135.0900', '4. close': '136.1200', '5. volume': '24726100'}
# 2019-09-10 {'1. open': '136.8000', '2. high': '136.8900', '3. low': '134.5100', '4. close': '136.0800', '5. volume': '28903400'}
# 2019-09-09 {'1. open': '139.5900', '2. high': '139.7500', '3. low': '136.4600', '4. close': '137.5200', '5. volume': '25773900'}
# 2019-09-06 {'1. open': '140.0300', '2. high': '140.1800', '3. low': '138.2000', '4. close': '139.1000', '5. volume': '20824500'}
# 2019-09-05 {'1. open': '139.1100', '2. high': '140.3800', '3. low': '138.7600', '4. close': '140.0500', '5. volume': '26101800'}
# ...
